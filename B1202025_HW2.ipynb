# %%
a='C,B,A'
b=['F','G','H']
a=a.split(',')
c=a+b

c[0]='K'
d=c.pop(1)
print(d)

del c[1:5]
c=c+['U']
print(c)
# Out:
# B
# ['K', 'U']

# %%
A=input('輸入一個八位數字')
print(A[4])
# Out:
# 輸入一個八位數字74654856
# 4

# %%
ID='My ID is B1202025'
C=ID.split()
print(len(C[0:]))
print(len(C[-1]))
# Out:
# 4
# 8

# %%
E="I'm a student"
e=E.split('m')
print(E[len(e[0])])
f=len(e[0])+1
print(f)
# Out:
# m
# 3
